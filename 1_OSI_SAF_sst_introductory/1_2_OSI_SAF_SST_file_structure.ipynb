# %% [markdown]
# <img src='https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/tools/frameworks/-/raw/main/img/OSI-SAF_banner.png' align='right' width='100%'/>

# %% [markdown]
# <a href="../Index.ipynb" target="_blank"><< Index</a>
# <br>
# <a href="./1_1c_OSI_SAF_SST_data_access_Eumetsat_data_store.ipynb" target="_blank"><< Accessing OSI SAF SST products through the EUMETSAT data store</a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="./1_3a_OSI_SAF_SST_mapping_Metop_Metagranules.ipynb" target="_blank">Mapping Global Metop AVHRR SST products >></a>

# %% [markdown]
# <font color="#138D75">**EUMETSAT OSI SAF Training Service**</font> <br>
# **Copyright:** 2024 EUMETSAT <br>
# **License:** MIT

# %% [markdown]
# <html>
#   <div style="width:100%">
#     <div style="float:left"><a href="https://mybinder.org/v2/git/https%3A%2F%2Fgitlab.eumetsat.int%2Feumetlab%2Foceans%2Focean-training%2Fsensors%2Flearn-osi-saf-sst/HEAD?urlpath=%2Ftree%2F1_OSI_SAF_sst_introductory%2F1_2_OSI_SAF_SST_file_structure.ipynb"><img src="https://mybinder.org/badge_logo.svg" alt="Open in Binder"></a></div>
#     <div style="float:left"><p>&emsp;</p></div>
#   </div>
# </html>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h3>Learn OSI SAF sea surface temperature: Introductory</h3></div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>PREREQUISITES </b>
#
# The following modules are prerequisites for this notebook, and will retrieve the data required here.
#   - **<a href="./1_1a_OSI_SAF_SST_data_access_IFREMER_Opensearch.ipynb" target="_blank">1_1a_OSI_SAF_SST_data_access_IFREMER_Opensearch.ipynb</a>**
#   - **<a href="./1_1b_OSI_SAF_SST_data_access_IFREMER_FTP.ipynb" target="_blank">1_1b_OSI_SAF_SST_data_access_IFREMER_FTP.ipynb</a>**
#
# </div>
# <hr>

# %% [markdown]
# # 1.2 Exploring OSI SAF SST product structure
# ### Data used
#
# | Product Description | Product Navigator | OSI SAF website link | OSI SAF Identifier |
# |:--------------------:|:-------------:|:-----------------:|:-----------------:|
# | Full resolution Metop-B Sea Surface Temperature metagranules | EO:EUM:DAT:METOP:MGR-SST | <a href="https://osi-saf.eumetsat.int/products/osi-204-b" target="_blank">link</a>| OSI-204-b |
# | Full resolution Metop-C Sea Surface Temperature metagranules | EO:EUM:DAT:METOP:MGR-SST | <a href="https://osi-saf.eumetsat.int/products/osi-204-c" target="_blank">link</a>| OSI-204-c |
# | Global Metop Sea Surface Temperature | EO:EUM:DAT:METOP:GLB-SST-NC | <a href="https://osi-saf.eumetsat.int/products/osi-201-b" target="_blank">link</a>| OSI-201-b |
# | Meteosat Sea Surface Temperature | EO:EUM:DAT:METEOSAT:OSIHSST-NC | <a href="https://osi-saf.eumetsat.int/products/osi-206-a" target="_blank">link</a>| OSI-206-a |
#
#
#
# ### Learning outcomes
#
# At the end of this notebook you will know;
# * What the OSI SAF SST netcdf files contain
# * What components are inside
# * How to explore the variables that are present
#
# <div class="alert alert-info" role="alert">
#
# ## <a id='TOC-TOP'></a>Contents
#
# </div>
#
#  1. [Querying OSI SAF SST file structure](#section1)
#
# <hr>

# %% [markdown]
# We begin by importing all of the libraries that we need to run this notebook. If you have built your python using the environment file provided in this repository, then you should have everything you need. For more information on building environment, please see the repository **<a href="../README.md" target="_blank">README</a>**.

# %%
# library imports 
import os                # a library that allows us access to basic operating system commands
import xarray as xr      # a library that supports the use of multi-dimensional arrays in Python

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section1'></a>1. Querying OSI SAF Sea Ice Concentration file structure
# [Back to top](#TOC-TOP)
#
# </div>

# %% [markdown]
# ### Full resolution Metop-B Sea Surface Temperature metagranules :

# %% [markdown]
# Let's start by defining the dataset we want to explore

# %%
directory = 'products/metagranules'

# %% [markdown]
# Explore the directory and open the netcdf file

# %%
for filename in os.listdir(directory):
    if filename.endswith(".nc"):
        nc = xr.open_dataset(directory + '/' + filename)
        print(filename)
# Out:
# 20240110071003-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_071003-v02.0-fv01.0.nc
# 20240110084903-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_084903-v02.0-fv01.0.nc
# 20240110093403-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_093403-v02.0-fv01.0.nc
# 20240110094603-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_094603-v02.0-fv01.0.nc
# 20240110100403-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_100403-v02.0-fv01.0.nc
# 20240110104003-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_104003-v02.0-fv01.0.nc
# 20240110111303-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_111303-v02.0-fv01.0.nc
# 20240110114003-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_114003-v02.0-fv01.0.nc
# 20240110115203-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_115203-v02.0-fv01.0.nc
# 20240110121903-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_121903-v02.0-fv01.0.nc
# 20240110123403-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_123403-v02.0-fv01.0.nc
# 20240110130703-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_130703-v02.0-fv01.0.nc
# 20240110131603-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_131603-v02.0-fv01.0.nc
# 20240110131903-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_131903-v02.0-fv01.0.nc
# 20240110133403-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_133403-v02.0-fv01.0.nc
# 20240110092203-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_092203-v02.0-fv01.0.nc
# 20240110092503-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_092503-v02.0-fv01.0.nc
# 20240110113703-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_113703-v02.0-fv01.0.nc
# 20240110121003-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_121003-v02.0-fv01.0.nc
# 20240110123103-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_123103-v02.0-fv01.0.nc
# 20240110124903-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_124903-v02.0-fv01.0.nc
# 20240110084003-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_084003-v02.0-fv01.0.nc
# 20240110124003-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_124003-v02.0-fv01.0.nc
# 20240110131003-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_131003-v02.0-fv01.0.nc
# 20240110133103-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_133103-v02.0-fv01.0.nc
# 20240110071603-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_071603-v02.0-fv01.0.nc
# 20240110084303-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_084303-v02.0-fv01.0.nc
# 20240110094903-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_094903-v02.0-fv01.0.nc
# 20240110101903-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_101903-v02.0-fv01.0.nc
# 20240110114903-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_114903-v02.0-fv01.0.nc
# 20240110120703-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_120703-v02.0-fv01.0.nc
# 20240110122203-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_122203-v02.0-fv01.0.nc
# 20240110123703-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_123703-v02.0-fv01.0.nc
# 20240110125803-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_125803-v02.0-fv01.0.nc
# 20240110134903-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_134903-v02.0-fv01.0.nc
# 20240110135503-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_135503-v02.0-fv01.0.nc
# 20240110084603-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_084603-v02.0-fv01.0.nc
# 20240110101603-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_101603-v02.0-fv01.0.nc
# 20240110102503-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_102503-v02.0-fv01.0.nc
# 20240110104903-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_104903-v02.0-fv01.0.nc
# 20240110112503-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_112503-v02.0-fv01.0.nc
# 20240110065803-OSISAF-L2P_GHRSST-SSTsubskin-AVHRR_SST_METOP_B-sstmgr_metop01_20240110_065803-v02.0-fv01.0.nc

# %% [markdown]
# We can now browse the file structure using xarray.
# The following content will list the contents of the loaded file.

# %%
nc
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 1, nj: 1080, ni: 2048)
# Coordinates:
#   * time                       (time) datetime64[ns] 2024-01-10T06:58:03
#     lat                        (nj, ni) float32 ...
#     lon                        (nj, ni) float32 ...
# Dimensions without coordinates: nj, ni
# Data variables: (12/14)
#     sea_surface_temperature    (time, nj, ni) float32 ...
#     sst_dtime                  (time, nj, ni) timedelta64[ns] ...
#     sses_bias                  (time, nj, ni) float32 ...
#     sses_standard_deviation    (time, nj, ni) float32 ...
#     dt_analysis                (time, nj, ni) float32 ...
#     wind_speed                 (time, nj, ni) float32 ...
#     ...                         ...
#     adi_dtime_from_sst         (time, nj, ni) float32 ...
#     sources_of_adi             (time, nj, ni) float32 ...
#     l2p_flags                  (time, nj, ni) int16 ...
#     quality_level              (time, nj, ni) float32 ...
#     satellite_zenith_angle     (time, nj, ni) float32 ...
#     solar_zenith_angle         (time, nj, ni) float32 ...
# Attributes: (12/47)
#     Conventions:                CF-1.4
#     title:                      Sea Surface Temperature
#     summary:                    The L2P product derived from METOP B AVHRR br...
#     references:                 Low Earth Orbiter Sea Surface Temperature Pro...
#     institution:                OSISAF
#     history:                    METEO-FRANCE/CMS LEOSAFO processor
#     ...                         ...
#     project:                    Group for High Resolution Sea Surface Tempera...
#     publisher_name:             The GHRSST Project Office
#     publisher_url:              http://www.ghrsst.org
#     publisher_email:            ghrsst-po@nceo.ac.uk
#     processing_level:           L2P
#     cdm_data_type:              swath

# %% [markdown]
# Have you had a detailed look at the diferent variables and attributes from the xarray output ?
# You can explore now explore individual variables. As an example :
# * sea_surface_temperature
# * quality_level

# %%
nc.variables['sea_ice_fraction']
# Out:
# <xarray.Variable (time: 1, nj: 1080, ni: 2048)>
# [2211840 values with dtype=float32]
# Attributes:
#     long_name:      sea ice fraction
#     standard_name:  sea_ice_area_fraction
#     units:
#     valid_min:      0
#     valid_max:      100
#     time_offset:    0.0
#     source:         ICE-OSISAF
#     comment:        Fractional sea ice cover from OSISAF ice product

# %%
nc.variables['quality_level']
# Out:
# <xarray.Variable (time: 1, nj: 1080, ni: 2048)>
# [2211840 values with dtype=float32]
# Attributes:
#     long_name:      quality level of SST pixel
#     valid_min:      0
#     valid_max:      5
#     flag_meanings:  no_data bad_data worst_quality low_quality acceptable_qua...
#     flag_values:    [0 1 2 3 4 5]
#     comment:        These are the overall quality indicators and are used for...

# %%
nc.close()

# %% [markdown]
# ### Global Metop Sea Surface Temperature :

# %% [markdown]
# Define the dataset we want to explore

# %%
directory = 'products/global'

# %% [markdown]
# Explore the directory and open the netcdf file

# %%
for filename in os.listdir(directory):
    if filename.endswith(".nc"):
        nc = xr.open_dataset(directory + '/' + filename)

# %% [markdown]
# We can now browse the file structure using xarray.
# The following content will list the contents of the loaded file.

# %%
nc
# Out:
# <xarray.Dataset>
# Dimensions:                    (time: 1, lat: 3600, lon: 7200)
# Coordinates:
#   * time                       (time) datetime64[ns] 2023-07-15
#   * lat                        (lat) float32 -89.97 -89.92 ... 89.92 89.97
#   * lon                        (lon) float32 -180.0 -179.9 ... 179.9 180.0
# Data variables: (12/14)
#     sea_surface_temperature    (time, lat, lon) float32 ...
#     sst_dtime                  (time, lat, lon) timedelta64[ns] ...
#     sses_bias                  (time, lat, lon) float32 ...
#     sses_standard_deviation    (time, lat, lon) float32 ...
#     dt_analysis                (time, lat, lon) float32 ...
#     wind_speed                 (time, lat, lon) float32 ...
#     ...                         ...
#     adi_dtime_from_sst         (time, lat, lon) float32 ...
#     sources_of_adi             (time, lat, lon) float32 ...
#     l2p_flags                  (time, lat, lon) int16 ...
#     quality_level              (time, lat, lon) float32 ...
#     satellite_zenith_angle     (time, lat, lon) float32 ...
#     solar_zenith_angle         (time, lat, lon) float32 ...
# Attributes: (12/47)
#     Conventions:                CF-1.4
#     title:                      Sea Surface Temperature
#     summary:                    The GLB L3C product derived from METOP B AVHR...
#     references:                 Low Earth Orbiter Sea Surface Temperature Pro...
#     institution:                OSISAF
#     history:                    METEO-FRANCE/CMS LEOSAFO processor
#     ...                         ...
#     project:                    Group for High Resolution Sea Surface Tempera...
#     publisher_name:             The GHRSST Project Office
#     publisher_url:              http://www.ghrsst.org
#     publisher_email:            ghrsst-po@nceo.ac.uk
#     processing_level:           L3C
#     cdm_data_type:              grid

# %%
nc.close()

# %% [markdown]
# ### AVHRR on Metop-B High latitudes SST :

# %% [markdown]
# You should have noticed all OSI SAF SST follow the same file structure. We can open a Metop-B/AVHRR SST file to have a look.

# %%
directory = 'products/High_latitudes/AVHRR/nh'

# %%
for filename in os.listdir(directory):
    if filename.endswith(".nc"):
        nc = xr.open_dataset(directory + '/' + filename)

# %%
nc
# Out:
# <xarray.Dataset>
# Dimensions:                              (time: 1, nj: 1080, ni: 2048)
# Coordinates:
#   * time                                 (time) datetime64[ns] 2023-06-01T23:...
#     lat                                  (nj, ni) float32 ...
#     lon                                  (nj, ni) float32 ...
# Dimensions without coordinates: nj, ni
# Data variables: (12/20)
#     land_mask                            (time, nj, ni) float32 ...
#     sea_surface_temperature              (time, nj, ni) float32 ...
#     sst_dtime                            (time, nj, ni) timedelta64[ns] ...
#     sses_bias                            (time, nj, ni) float32 ...
#     sses_standard_deviation              (time, nj, ni) float32 ...
#     dt_analysis                          (time, nj, ni) float32 ...
#     ...                                   ...
#     processing_flags                     (time, nj, ni) float32 ...
#     probability_of_water                 (time, nj, ni) float32 ...
#     probability_of_ice                   (time, nj, ni) float32 ...
#     large_scale_correlated_uncertainty   (time, nj, ni) float32 ...
#     uncorrelated_uncertainty             (time, nj, ni) float32 ...
#     synoptically_correlated_uncertainty  (time, nj, ni) float32 ...
# Attributes: (12/57)
#     topiccategory:              Oceans Climatology Meteorology Atmosphere
#     keywords:                   Sea Ice Skin Temperature, Sea Surface Tempera...
#     gcmd_keywords:              Cryosphere > Sea Ice > Sea Ice Surface Temper...
#     activity_type:              Space borne instrument
#     Conventions:                CF-1.6
#     spatial_resolution:         1.1km at nadir
#     ...                         ...
#     sensor:                     AVHRRMTB
#     northernmost_latitude:      57.905
#     easternmost_longitude:      179.999
#     southernmost_latitude:      41.168
#     westernmost_longitude:      -179.999
#     comment:                    This product is based on IR swath data that a...

# %%
nc.close()

# %% [markdown]
# <a href="../Index.ipynb" target="_blank"><< Index</a>
# <br>
# <a href="./1_1c_OSI_SAF_SST_data_access_Eumetsat_data_store.ipynb" target="_blank"><< Accessing OSI SAF SST products through the EUMETSAT data store</a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="./1_3a_OSI_SAF_SST_mapping_Metop_Metagranules.ipynb" target="_blank">Mapping Global Metop AVHRR SST products >></a>
# <hr>
# <a href="https://gitlab.eumetsat.int/eumetlab/ocean">View on GitLab</a> | <a href="https://training.eumetsat.int/">EUMETSAT Training</a> | <a href=mailto:ops@eumetsat.int>Contact helpdesk for support </a> | <a href=mailto:Copernicus.training@eumetsat.int>Contact our training team to collaborate on and reuse this material</a></span></p>
